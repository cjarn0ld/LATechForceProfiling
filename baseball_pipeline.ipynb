# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
import glob

# %%
def calculate_variables(data, data_type, path=None, filename=None):
    
    def compute_biomechanics(force, dt, m_body, bw):
        max_force = np.max(force, axis=1)
        a = (force - bw) / m_body
        v = sp.integrate.cumtrapz(a, dx=dt)  # Adding initial value for matching array size
        max_v = np.max(v, axis = 1)
        print(max_v)
        F_trimmed = force - bw
        peak_power = np.dot(max_force, max_v)
        concentric_impulse = sp.integrate.cumtrapz(force, dx=dt)  # Cumulative impulse
        E_RFD = np.max(np.diff(force) / dt, axis=1)  # Taking max along axis 1
        
        return max_force, peak_power, np.max(concentric_impulse, axis=1), E_RFD
   
    def player_exists_in_directory(player_name, directory_path):
        # List all files in the directory
        files_in_directory = os.listdir(directory_path)

        # Check if any filename starts with the player's name
        for file in files_in_directory:
            if file.startswith(player_name):
                return True  # A file with the player's name exists in the directory

        return False  # No file with the player's name was found in the directory


    dt = 0.005
    bw = data['Time_s_'][4]
    m_body = round(bw/9.81, 2)
    


    if data_type == 'hitting':
        if 'Right_handed' in path:
            drive_direction = 'R'
            stride_direction = 'L'
        else:
            drive_direction = 'L'
            stride_direction = 'R'
        
        # Ensure column existence before extracting data to prevent potential KeyErrors
        columns_to_check_drive = [f'RawFx_{drive_direction}_N_', f'RawFy_{drive_direction}_N_', f'RawFz_{drive_direction}_N_']
        columns_to_check_stride = [f'RawFx_{stride_direction}_N_', f'RawFy_{stride_direction}_N_', f'RawFz_{stride_direction}_N_']
        
        for col in columns_to_check_drive:
            if col not in data.columns:
                raise KeyError(f"Column '{col}' not found in the DataFrame for drive leg")
        for col in columns_to_check_stride:
            if col not in data.columns:
                raise KeyError(f"Column '{col}' not found in the DataFrame for stride leg")
            
        force_drive = np.array([data[f'RawFx_{drive_direction}_N_'][9:].values, 
                                data[f'RawFy_{drive_direction}_N_'][9:].values, 
                                data[f'RawFz_{drive_direction}_N_'][9:].values])
        
        force_stride = np.array([data[f'RawFx_{stride_direction}_N_'][9:].values, 
                                data[f'RawFy_{stride_direction}_N_'][9:].values, 
                                data[f'RawFz_{stride_direction}_N_'][9:].values])
        
        max_force_drive, peak_power_drive, max_impulse_drive, _ = compute_biomechanics(force_drive, dt, m_body, bw)
        max_force_stride, peak_power_stride, max_impulse_stride, _ = compute_biomechanics(force_stride, dt, m_body, bw)

        return pd.DataFrame({
            'mass': m_body,
            'hitting_drive_Fx': max_force_drive[0],
            'hitting_drive_Fy': max_force_drive[1],
            'hitting_drive_Fz': max_force_drive[2],
            'hitting_stride_Fx': max_force_stride[0],
            'hitting_stride_Fy': max_force_stride[1],
            'hitting_stride_Fz': max_force_stride[2],
            'hitting_peak_power_stride': peak_power_stride,
            'hitting_peak_power_drive': peak_power_drive,
            'hitting_max_impulse_x': max_impulse_stride[0],
            'hitting_max_impulse_y': max_impulse_stride[1],
            'hitting_max_impulse_z': max_impulse_stride[2] 
        }, index=[0])

    
    elif data_type == 'jump':
        #print(filename)
        player_name = filename.split('-')[0].strip()  # This will give "LaRocca, Jake"
        #print(f'Player name: {player_name}')

        # Paths to the right-handed and left-handed directories
        right_handed_directory = '/Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /Hitting_BASEBALL/Right_handed'
        left_handed_directory = '/Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /Hitting_BASEBALL/Left_handed'

        # Check if player's name exists in the right_handed or left_handed directories
        player_in_right_handed = player_exists_in_directory(player_name, right_handed_directory)
        player_in_left_handed = player_exists_in_directory(player_name, left_handed_directory)

        #print(f"Checking for {player_name} in: {right_handed_directory}")
        #print(f"Exists? {player_in_right_handed}")
        print(path)
        if 'drive_leg' in path:
            print(f'Processing path: {path}')
            
            if player_in_right_handed:
                leg = 'R'
            elif player_in_left_handed:
                leg = 'L'
            else:
                leg = None
            prefix = 'lmj_drive'
        else:
            if player_in_right_handed:
                leg = 'L'
            elif player_in_left_handed:
                leg = 'R'
            else:
                leg = None
            prefix = 'lmj_stride'

        print(f'Player name: {player_name} : {leg}') 


        #print(np.max(data[f"RawFx_{leg}_N_"]))
        force_leg = np.array([data[f'RawFx_{leg}_N_'][9:], data[f'RawFy_{leg}_N_'][9:], data[f'RawFz_{leg}_N_'][9:]])
        print(force_leg)
        max_force_leg, peak_power_leg, max_impulse_leg, E_RFD_leg = compute_biomechanics(force_leg, dt, m_body,bw)

        ''' print({
            f'{prefix}_Fx': max_force_leg[0],
            f'{prefix}_Fy': max_force_leg[1],
            f'{prefix}_Fz': max_force_leg[2],
            f'{prefix}_peak_force': np.sum(max_force_leg),
            f'{prefix}_peak_power': peak_power_leg,
            f'{prefix}_max_impulse_x': max_impulse_leg[0],
            f'{prefix}_max_impulse_y': max_impulse_leg[1],
            f'{prefix}_max_impulse_z': max_impulse_leg[2],
            f'{prefix}_E-RFD_x': E_RFD_leg[0],
            f'{prefix}_E-RFD_y': E_RFD_leg[1],
            f'{prefix}_E-RFD_z': E_RFD_leg[2]
        })'''
        return pd.DataFrame({
            f'{prefix}_Fx': max_force_leg[0],
            f'{prefix}_Fy': max_force_leg[1],
            f'{prefix}_Fz': max_force_leg[2],
            f'{prefix}_peak_force': np.sum(max_force_leg),
            f'{prefix}_peak_power': peak_power_leg,
            f'{prefix}_max_impulse_x': max_impulse_leg[0],
            f'{prefix}_max_impulse_y': max_impulse_leg[1],
            f'{prefix}_max_impulse_z': max_impulse_leg[2],
            f'{prefix}_E-RFD_x': E_RFD_leg[0],
            f'{prefix}_E-RFD_y': E_RFD_leg[1],
            f'{prefix}_E-RFD_z': E_RFD_leg[2]
        }, index=[0])

    

    elif data_type == 'broad_jump':
        
        # Assume both legs exert force during a broad jump, so we sum forces from both legs.
        force_R = np.array([data['RawFx_R_N_'][9:], data['RawFy_R_N_'][9:], data['RawFz_R_N_'][9:]])
        force_L = np.array([data['RawFx_L_N_'][9:], data['RawFy_L_N_'][9:], data['RawFz_L_N_'][9:]])
       
        max_L = np.max(np.sqrt(np.sum(force_L**2, axis=0)))
        max_R = np.max(np.sqrt(np.sum(force_R**2, axis=0)))
        dt = 0.005
        bw = data['Time_s_'][4]
        m_body = round(bw/9.81, 2)
        
        force_total = force_R + force_L
        max_force_total, peak_power_total, max_impulse_total, E_RFD_total = compute_biomechanics(force_total, dt, m_body, bw)
        

        return pd.DataFrame({
            'broad_jump_Fx': max_force_total[0],
            'broad_jump_Fy': max_force_total[1],
            'broad_jump_Fz': max_force_total[2],
            'right_leg_max_force': max_R,
            'right_leg_force_max_x': np.max(data['RawFx_R_N_'][9:]),
            'right_leg_force_max_y': np.max(data['RawFy_R_N_'][9:]),
            'right_leg_force_max_z': np.max(data['RawFz_R_N_'][9:]),
            'left_leg_max_force': max_L,
            'left_leg_force_max_x': np.max(data['RawFx_L_N_'][9:]),
            'left_leg_force_max_y': np.max(data['RawFy_L_N_'][9:]),
            'left_leg_force_max_z': np.max(data['RawFz_L_N_'][9:]),
            'broad_jump_peak_force': np.sum(max_force_total),
            'broad_jump_peak_power': peak_power_total,
            'broad_jump_max_impulse_x': max_impulse_total[0],
            'broad_jump_max_impulse_y': max_impulse_total[1],
            'broad_jump_max_impulse_z': max_impulse_total[2],
            'broad_jump_E-RFD_x': E_RFD_total[0],
            'broad_jump_E-RFD_y': E_RFD_total[1],
            'broad_jump_E-RFD_z': E_RFD_total[2]
        }, index=[0])

# %%
def extract_name_from_filename(filename):
    # Extract the "Lastname, Firstname" part from the filename
    name_part = filename.split('-')[0].strip()
    
    # Split the name into last and first names
    last_name, first_name = name_part.split(',')
    #print(first_name.strip() + " " + last_name.strip())
    
    # Return formatted name "Firstname Lastname"
    return first_name.strip() + " " + last_name.strip()


def process_excel_files(path, jump_type):
    output_data = []
    
    for filename in os.listdir(path):
        if filename.endswith('.xlsx'):
            #print(f"Processing file: {filename}")  # to see which file you're processing
            
            player_name = extract_name_from_filename(filename)
            
            data = pd.read_excel(os.path.join(path, filename), engine='openpyxl')
            results = calculate_variables(data, jump_type, path, filename)
            
            # Add the player's name to the beginning of the results DataFrame
            results.insert(0, 'Player Name', player_name)
            
            output_data.append(results)

    return pd.concat(output_data, axis=0)


# ... [All the previous functions remain unchanged]

def main():
    right_handed_path = '/Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /Hitting_BASEBALL/Right_handed'
    left_handed_path = '/Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /Hitting_BASEBALL/Left_handed'
    
    lmj_drive_path = '/Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg'
    lmj_stride_path = '/Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg'
    broad_jump_path = '/Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /BROAD_BASEBALL/hitters'
    
    right_handed_data = process_excel_files(right_handed_path, 'hitting')
    left_handed_data = process_excel_files(left_handed_path, 'hitting')
    lmj_drive_data = process_excel_files(lmj_drive_path, 'jump')
    lmj_stride_data = process_excel_files(lmj_stride_path, 'jump')
    broad_jump_data = process_excel_files(broad_jump_path, 'broad_jump')

    combined_data = pd.concat([right_handed_data, left_handed_data, lmj_drive_data, lmj_stride_data, broad_jump_data], axis=0)
    combined_data.reset_index(drop=True, inplace=True)
    
    # Group by player name and calculate the average for each metric
    averaged_data = combined_data.groupby('Player Name').mean().reset_index()

    # Save averaged_data to a new Excel file
    output_file_path = "/Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /baseball_output_data.xlsx"
    averaged_data.to_excel(output_file_path, index=False)
    print(f"Data saved to {output_file_path}")

if __name__ == "__main__":
    main()
# Out:
# [-0.04172777 -0.04922018 -0.01919365]
# [-0.05549096 -0.050001   -0.02777978]
# [-0.04052891 -0.05067304 -0.02360808]
# [-0.0561066  -0.0491034  -0.02505182]
# [-0.04238354 -0.04797104 -0.02340802]
# [-0.05555    -0.05064568 -0.02565113]
# [-0.0440832  -0.04931274 -0.02644769]
# [-0.0544016  -0.04891639 -0.02874435]
# [-0.03918688 -0.05036313 -0.01302938]
# [-0.05046352 -0.04849916 -0.03999445]
# [-0.0490528  -0.04856869 -0.04904842]
# [-0.06385405 -0.04736413 -0.00740611]
# [-0.04373561 -0.04884833 -0.02301903]
# [-0.05544364 -0.04922505 -0.02664751]
# [-0.03600953 -0.0467046  -0.00894561]
# [-0.04882598 -0.04895265 -0.04933981]
# [-0.04429957 -0.04939263 -0.02580153]
# [-0.05536984 -0.04924756 -0.02395751]
# [-0.04186427 -0.05004528 -0.0222832 ]
# [-0.05423289 -0.04835828 -0.02612181]
# [-0.04343146 -0.04981437 -0.02922592]
# [-0.06001001 -0.04901711 -0.02072717]
# [-0.03722741 -0.04901143 -0.01018163]
# [-0.05302203 -0.05054552 -0.03279003]
# [-0.03982985 -0.04997583 -0.02157798]
# [-0.05747758 -0.04836585 -0.02633879]
# [-0.03905358 -0.04813927 -0.01346293]
# [-0.05133703 -0.0499931  -0.04054759]
# [-0.0404045  -0.05112133 -0.01212203]
# [-0.04962264 -0.04831568 -0.04331036]
# [-0.03988449 -0.04961584 -0.01829483]
# [-0.05997807 -0.05001653 -0.02280581]
# [-0.04458718 -0.0481251  -0.02919936]
# [-0.05938989 -0.05044966 -0.02087867]
# [-0.04326499 -0.04923927 -0.02443706]
# [-0.05663445 -0.04862725 -0.02462903]
# [-0.03838999 -0.04959253 -0.02423087]
# [-0.05824623 -0.05042132 -0.02482972]
# [-0.03773494 -0.04969817 -0.00138832]
# [-0.0497108  -0.04959134 -0.04543153]
# [-0.04522359 -0.04888534 -0.0355401 ]
# [-0.06025687 -0.05039008 -0.01218434]
# [-0.04283911 -0.04940094 -0.01986626]
# [-0.05458888 -0.05033725 -0.03009293]
# [-0.04511261 -0.04725405 -0.03070277]
# [-0.05601291 -0.04899908 -0.01912388]
# [-0.04610775 -0.04864392 -0.03674382]
# [-0.06574384 -0.049344   -0.0124244 ]
# [-0.04242662 -0.04768269 -0.02286549]
# [-0.0557977  -0.04981566 -0.02658121]
# [-0.04234724 -0.04918776 -0.02464285]
# [-0.0560396  -0.04957434 -0.02529342]
# [-0.04839088 -0.048976   -0.04905232]
# [-0.06354576 -0.04459263 -0.01194096]
# [-0.0441321  -0.04846725 -0.02651734]
# [-0.05237841 -0.04889551 -0.02354006]
# [-0.040603   -0.04737209 -0.02135489]
# [-0.05509823 -0.04888232 -0.02910345]
# [-0.04467366 -0.05067874 -0.03047941]
# [-0.05886918 -0.04929666 -0.0153939 ]
# [-0.03950417 -0.0475174  -0.01003612]
# [-0.04902975 -0.04809864 -0.04493576]
# [-0.03831803 -0.04853545 -0.01211848]
# [-0.05108101 -0.05003973 -0.04134458]
# [-0.04144177 -0.04908354 -0.02428682]
# [-0.05744279 -0.05002784 -0.02415448]
# [-0.0430633 -0.0486579 -0.0257698]
# [-0.05935544 -0.05025026 -0.01514464]
# [-0.04150875 -0.04877992 -0.02379785]
# [-0.05714433 -0.04900373 -0.02562414]
# [-0.04255901 -0.04726914 -0.02312321]
# [-0.05870715 -0.04978519 -0.02019987]
# [-0.04437186 -0.04861914 -0.0329172 ]
# [-0.0595486  -0.0480656  -0.01284881]
# [-0.04216708 -0.04862997 -0.02295547]
# [-0.05560546 -0.04927841 -0.02573692]
# [-0.0421676  -0.04864722 -0.02146205]
# [-0.05509871 -0.04873772 -0.02735662]
# [-0.04905252 -0.0490391  -0.04904962]
# [-0.06094132 -0.0495784  -0.008991  ]
# [-0.04089449 -0.05010895 -0.02145428]
# [-0.05511218 -0.04895697 -0.0277242 ]
# [-0.04518917 -0.0496943  -0.02340577]
# [-0.05497274 -0.04922529 -0.02563495]
# [-0.04265757 -0.04888253 -0.02130067]
# [-0.0540712  -0.04853383 -0.02706879]
# [-0.03536263 -0.048696   -0.0082688 ]
# [-0.05265396 -0.0495792  -0.03550304]
# [-0.03966781 -0.04872202 -0.01521711]
# [-0.05572477 -0.04968693 -0.03395872]
# [-0.04873681 -0.04773145 -0.04290187]
# [-0.05944554 -0.04975884 -0.00728835]
# [-0.0425083  -0.04940834 -0.02375666]
# [-0.05472147 -0.04926583 -0.02525432]
# [-0.04818974 -0.0477405  -0.04091192]
# [-0.0621353  -0.04811617 -0.01556819]
# [-0.04433956 -0.04836969 -0.02718652]
# [-0.05285732 -0.04887969 -0.02325006]
# [-0.03969171 -0.04867872 -0.02149294]
# [-0.05609905 -0.04919601 -0.0258998 ]
# [-0.04492385 -0.0474944  -0.03322782]
# [-0.05763632 -0.04987727 -0.01956989]
# [-0.04232748 -0.04747602  0.07744209]
# [-0.04918845 -0.04875056 -0.04917856]
# [-0.04328544 -0.04865472 -0.02142806]
# [-0.05516135 -0.04925634 -0.02760182]
# [-0.04039402 -0.0476047  -0.00987105]
# [-0.05334023 -0.04916612 -0.03815872]
# [-0.04759165 -0.05046363 -0.03651457]
# [-0.06180642 -0.04898227 -0.00912142]
# [-0.04161668 -0.04928472 -0.0204152 ]
# [-0.05405292 -0.04914515 -0.02957426]
# [-0.04120241 -0.05108655 -0.01860401]
# [-0.05505346 -0.04753558 -0.03026314]
# [-0.04319788 -0.05004434 -0.02292566]
# [-0.05378348 -0.04981602 -0.02634405]
# [-0.03923441 -0.04789799 -0.01175063]
# [-0.05083999 -0.04794481 -0.03576876]
# [-0.04046999 -0.04894659 -0.02306312]
# [-0.05691049 -0.04941644 -0.0256325 ]
# [-0.04905153 -0.04905153 -0.04905153]
# [-0.04905153 -0.04905153 -0.04905153]
# [-0.04028956 -0.0481909  -0.02290821]
# [-0.05706943 -0.04995714 -0.02668824]
# [-0.04045921 -0.05053365 -0.0104557 ]
# [-0.05552644 -0.04745758 -0.02935322]
# [-0.04210488 -0.05018377 -0.01609635]
# [-0.05597438 -0.05071039 -0.02576422]
# [-0.03923183 -0.05042987 -0.01779987]
# [-0.05394445 -0.04749478 -0.03108355]
# [-0.04300601 -0.04986021 -0.02370665]
# [-0.05818412 -0.04774632 -0.02626349]
# [-0.04905161 -0.04905161 -0.04905161]
# [-0.04905161 -0.04905161 -0.04905161]
# [-0.04250395 -0.05017293 -0.02338115]
# [-0.05603334 -0.04626505 -0.02472107]
# [-0.0407363  -0.04974729 -0.0083757 ]
# [-0.05110477 -0.04923712 -0.03971758]
# [-0.04327147 -0.05083564 -0.01868282]
# [-0.05351513 -0.04817148 -0.03056338]
# [-0.04050979 -0.04757282 -0.02106608]
# [-0.05587435 -0.05036408 -0.02868443]
# [-0.04315672 -0.04869237 -0.02179688]
# [-0.05449507 -0.05006442 -0.02742133]
# [-0.04340866 -0.04858637 -0.02105254]
# [-0.05639514 -0.04963664 -0.02570411]
# [-0.04833405 -0.04810641 -0.04905823]
# [-0.061065   -0.04879087 -0.00768897]
# [-0.04365603 -0.04944378 -0.02303708]
# [-0.05339193 -0.04954957 -0.02676515]
# [-0.04276172 -0.05014423 -0.02625719]
# [-0.05512085 -0.04832117 -0.02267884]
# [-0.04745703 -0.04875545 -0.04157785]
# [-0.05849247 -0.04829527 -0.0137059 ]
# [-0.04314533 -0.04899754 -0.02166023]
# [-0.05450055 -0.04984704 -0.02751313]
# [-0.04553431 -0.04958506 -0.02877249]
# [-0.05746345 -0.05029678 -0.02025772]
# [-0.0380392  -0.04825025 -0.01523415]
# [-0.05489219 -0.04808739 -0.03297286]
# [-0.04171911 -0.04995671 -0.02213135]
# [-0.05569029 -0.04926267 -0.02659644]
# [-0.04074428 -0.04852253 -0.02432698]
# [-0.05661884 -0.04968588 -0.02463651]
# [-0.05458914 -0.04996658 -0.02848776]
# [-0.04179149 -0.04883033 -0.02092761]
# [-0.05651778 -0.04869449 -0.02478159]
# [-0.03911699 -0.04952728 -0.0232457 ]
# [-0.05124202 -0.04964252 -0.03398623]
# [-0.04491521 -0.04946169 -0.01368411]
# [-0.05603677 -0.05031457 -0.01895275]
# [-0.0421468  -0.04920144 -0.02496075]
# [-0.05975997 -0.04845363 -0.00928655]
# [-0.04550557 -0.05240061 -0.03256526]
# [-0.05557188 -0.04783644 -0.01507128]
# [-0.04635266 -0.05053672 -0.03276707]
# [-0.05287628 -0.05069472 -0.03009897]
# [-0.04423174 -0.04823355 -0.0184058 ]
# [-0.05264079 -0.04883011 -0.02781831]
# [-0.04357185 -0.04829442 -0.02261442]
# [-0.05551253 -0.04881697 -0.02566856]
# [-0.04225713 -0.04823409 -0.02367983]
# [-0.05679076 -0.04871786 -0.02462917]
# [-0.0413478  -0.04983597 -0.02400488]
# [-0.05541707 -0.04943274 -0.03069406]
# [-0.03873508 -0.04780397 -0.01743991]
# [-0.05251273 -0.04610934 -0.02781388]
# [-0.04452029 -0.05274153 -0.02074454]
# [-0.05733071 -0.04861495 -0.00393544]
# [-0.0492568  -0.04832783 -0.04943422]
# [-0.05467953 -0.04802208 -0.01862306]
# [-0.04594012 -0.0491965  -0.03086277]
# [-0.05735762 -0.04906935 -0.00455798]
# [-0.04835701 -0.04926191 -0.03993652]
# [-0.05595235 -0.04869508 -0.02461453]
# [-0.04319356 -0.05007791 -0.02415005]
# [-0.05733082 -0.05004899 -0.0226904 ]
# [-0.0432232  -0.04778061 -0.02638481]
# [-0.05278691 -0.04985164 -0.02846039]
# [-0.0445968  -0.04974988 -0.02180578]
# [-0.05319004 -0.05017319 -0.03381372]
# [-0.03707946 -0.05030534 -0.01177419]
# [-0.05717427 -0.05082536 -0.0241192 ]
# [-0.04281778 -0.04731796 -0.02543515]
# [-0.05767812 -0.04875935 -0.02279695]
# [-0.04169926 -0.05017364 -0.02603201]
# [-0.0564398  -0.05025031 -0.02408835]
# [-0.04296916 -0.04834524 -0.02501918]
# [-0.05484269 -0.04895277 -0.02464617]
# [-0.04446242 -0.04904545 -0.02491874]
# [-0.05911978 -0.04937863 -0.01590491]
# [-0.04288331 -0.0494007  -0.03009791]
# [-0.06147053 -0.04846439 -0.01377667]
# [-0.04633002 -0.05012201 -0.03715268]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: LaRocca, Jake : R
# [[ 26.858312  28.479854  28.732004 ...  13.761684  15.798918  10.82221 ]
#  [ 36.81646   34.251707  32.270614 ...   5.125219   3.221375   8.854697]
#  [880.362749 880.231127 880.231127 ...   4.41316   -4.532121   0.      ]]
# [-0.04749809 -0.04705767  1.44273614]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Netterville, Slade : R
# [[ 6.80515700e+00  7.63111100e+00  7.83027100e+00 ...  5.35894000e+00
#    3.26449000e+00  7.95062300e+00]
#  [ 5.46625000e-01  2.05936100e+00 -1.64671500e+00 ...  4.67337300e+00
#    6.43514300e+00  5.18987200e+00]
#  [ 7.52772248e+02  7.52772248e+02  7.57304369e+02 ... -1.31622000e-01
#    0.00000000e+00  0.00000000e+00]]
# [-0.04857956 -0.04896501  1.50552275]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Berch, Thaxton : R
# [[ 4.17170900e+00  3.12029700e+00  6.39621300e+00 ... -2.14240900e+00
#    4.49705000e-01  2.85223600e+00]
#  [ 1.21077810e+01  1.39394900e+01  1.14901020e+01 ...  1.14767800e+00
#   -9.33514000e-01 -4.36637000e-01]
#  [ 7.55271404e+02  7.55271404e+02  7.59686894e+02 ... -4.53212100e+00
#   -4.53212100e+00 -4.53212100e+00]]
# [-0.04882129 -0.04822912  1.37248935]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Corona, Jorge : R
# [[ 4.67352000e-01  6.48535300e+00  2.33979000e+00 ...  2.46353900e+00
#    2.24550300e+00  3.52707200e+00]
#  [ 1.24199640e+01  1.04828580e+01  1.14827850e+01 ...  7.23935700e+00
#    7.55020900e+00  7.38968000e+00]
#  [ 9.44938318e+02  9.44938318e+02  9.44938318e+02 ... -4.53212100e+00
#   -4.53212100e+00 -4.53212100e+00]]
# [-0.04887075 -0.04845586  1.22255971]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Coates, Colton : R
# [[ 4.07888000e+00  5.06603300e+00  4.73733000e-01 ... -2.46368500e+00
#    2.54337000e-01 -3.68377200e+00]
#  [-2.72757850e+01 -2.86873930e+01 -2.83974150e+01 ... -8.48474600e+00
#   -7.31770900e+00 -1.26358340e+01]
#  [ 8.30848557e+02  8.35264048e+02  8.26316436e+02 ... -8.94761200e+00
#   -4.53212100e+00 -8.94761200e+00]]
# [-0.04878141 -0.05070132  1.24569871]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: McLeod, Logan : R
# [[-22.413025 -21.703432 -23.890861 ...  18.160668  18.301655  21.859006]
#  [-13.646466 -10.39388  -14.828584 ...   3.886992   1.484476   4.453636]
#  [815.313439 815.19914  815.214132 ...  -4.547113  -4.547113  -4.547113]]
# [-0.05036966 -0.04976808  1.19035667]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Smith, Jake : R
# [[  2.581051   3.214085   1.170448 ...  -6.72121   -2.272159  -3.633207]
#  [ 56.829636  57.666946  52.605638 ...   6.214123  10.175496  11.146475]
#  [728.931466 720.115477 720.247099 ...   0.        -4.532121   0.      ]]
# [-0.04885798 -0.04521272  0.92430347]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Netterville, Slade : R
# [[ 1.80300170e+01  1.21784160e+01  1.17945700e+01 ...  1.22352350e+01
#    1.18423140e+01  1.12867120e+01]
#  [ 7.07123700e+00  3.80610500e+00  3.61196100e+00 ...  1.81672500e+00
#    1.03656400e+00  1.73896200e+00]
#  [ 7.57737220e+02  7.53205099e+02  7.53205099e+02 ...  0.00000000e+00
#   -4.53212100e+00 -1.31622000e-01]]
# [-0.04806567 -0.04869551  1.66514084]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Myers, Adarius : R
# [[-2.71164980e+01 -2.40638490e+01 -1.87169300e+01 ... -8.03050000e-02
#   -8.05150000e-01 -2.79705000e-01]
#  [-5.36211470e+01 -4.43802650e+01 -4.33417620e+01 ... -1.66071400e+00
#   -1.91318000e-01 -4.05744200e+00]
#  [ 8.60767636e+02  8.52065946e+02  8.47764755e+02 ... -1.31622000e-01
#    4.40049800e+00  4.40049800e+00]]
# [-0.05051321 -0.05185111  1.43685304]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: LaRocca, Jake : R
# [[ 3.11337690e+01  3.29313090e+01  3.57557960e+01 ...  1.46296300e+01
#    1.86038150e+01  1.65587720e+01]
#  [ 1.46138400e+00  3.78197000e-01  3.64430400e+00 ... -2.64101100e+00
#   -1.09285690e+01 -1.02533470e+01]
#  [ 8.78927534e+02  8.83343025e+02  8.83343025e+02 ... -1.31622000e-01
#    0.00000000e+00  4.40049800e+00]]
# [-0.04725375 -0.04899598  1.19070894]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Coates, Colton : R
# [[-1.33726580e+01 -1.12322040e+01 -1.18420890e+01 ...  1.65400000e-03
#    3.58175200e+00 -2.29730000e-02]
#  [-2.79517600e+01 -2.94380860e+01 -2.82471310e+01 ...  1.91152200e+00
#   -6.25860000e-01  5.75224900e+00]
#  [ 8.34643860e+02  8.43604133e+02  8.34643860e+02 ... -4.53212100e+00
#    1.26610000e-02 -1.31622000e-01]]
# [-0.04977662 -0.05074339  1.09188496]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Snider, Reid : R
# [[ 10.110636  10.325218  10.528127 ...  -1.223791  -3.669704  -1.203401]
#  [-46.890885 -45.161183 -42.771353 ...  -6.287474  -3.006225  -7.74266 ]
#  [831.689914 831.689914 831.689914 ...   0.         0.         4.544782]]
# [-0.04844771 -0.05176007  1.32802837]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Comeaux, Grant : R
# [[-2.11527300e+00 -2.57861900e+00 -4.27185700e+00 ... -1.01996770e+01
#   -9.11999400e+00 -1.50125720e+01]
#  [ 9.30112000e+00  8.76871500e+00  1.17724810e+01 ... -9.85579000e-01
#   -5.14892800e+00 -3.95463900e+00]
#  [ 8.36551341e+02  8.36551341e+02  8.36551341e+02 ... -1.31622000e-01
#   -1.31622000e-01 -1.31622000e-01]]
# [-0.04918734 -0.04851234  1.36362537]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Comeaux, Grant : R
# [[ 16.814991  14.627076  17.157392 ... -12.479141 -11.922793 -10.685993]
#  [  9.627905  13.0501    16.243085 ...  -5.492738  -3.73029   -7.181327]
#  [834.642959 830.371753 821.555763 ...   0.         4.400498  -4.532121]]
# [-0.04811582 -0.0483757   1.52772153]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Safford, Will : L
# [[ 2.69933900e+00 -3.13093000e-01  2.58738400e+00 ...  1.49537300e+00
#    2.82848900e+00  2.30524300e+00]
#  [ 6.35711100e+00  5.20686400e+00  2.83138500e+00 ...  2.28271300e+00
#    4.87999600e+00  3.92290400e+00]
#  [ 7.76344078e+02  7.76344078e+02  7.76344078e+02 ...  0.00000000e+00
#    0.00000000e+00  4.31480800e+00]]
# [-0.04897469 -0.04867771  1.59451251]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Cobb, Baylor : L
# [[-1.80230000e-02 -4.27056200e+00 -1.30998600e+00 ... -9.23842100e+00
#   -1.47324690e+01 -9.74624400e+00]
#  [ 4.47749000e+00  7.35042200e+00  5.97152900e+00 ...  1.92766870e+01
#    1.95742190e+01  1.72078220e+01]
#  [ 8.82266937e+02  8.77952129e+02  8.73448176e+02 ...  3.66210000e-02
#   -4.46733300e+00  3.66210000e-02]]
# [-0.04916964 -0.04871401  1.62202489]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Guinn, Hutson : R
# [[ 33.458917  31.48955   28.801923 ...  -5.868379  -9.76115  -10.536286]
#  [ 34.550181  39.529465  38.944168 ...  -5.597929  -7.793961  -6.228463]
#  [876.104204 871.688713 871.688713 ...  -4.532121   0.         0.      ]]
# [-0.04725248 -0.0469999   0.9341312 ]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Brown, RJ : R
# [[-4.77353100e+00 -2.82298000e+00 -7.53438000e-01 ... -2.36942100e+00
#    1.28352600e+00 -1.40483600e+00]
#  [-1.49947500e+00 -1.00925300e+00  5.78471600e+00 ... -4.15276600e+00
#   -2.09803200e+00 -1.29592500e+00]
#  [ 8.37413689e+02  8.33013191e+02  8.24052918e+02 ...  4.41316000e+00
#    1.26610000e-02  1.26610000e-02]]
# [-0.04927159 -0.04912205  1.47545403]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Davis, Dalton : R
# [[ 3.58987300e+00  3.16542700e+00  1.07398610e+01 ...  1.13893100e+00
#    9.59278000e-01 -2.65428500e+00]
#  [-9.01372400e+00 -5.12797000e+00 -8.50281400e+00 ...  3.52384200e+00
#    2.79908800e+00 -3.60787000e-01]
#  [ 9.08938551e+02  9.04639691e+02  9.00224200e+02 ... -1.31622000e-01
#    4.40049800e+00  4.54478200e+00]]
# [-0.0488538  -0.0494572   1.84814171]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Cobb, Baylor : L
# [[-2.10900900e+00  1.34885400e+00  2.48181400e+00 ... -1.93251190e+01
#   -2.00297640e+01 -1.53138870e+01]
#  [-2.78817050e+01 -2.49773070e+01 -2.95120260e+01 ...  1.12984020e+01
#    1.25981980e+01  1.20922080e+01]
#  [ 8.78399799e+02  8.78399799e+02  8.87318324e+02 ...  3.66210000e-02
#    3.66210000e-02  3.66210000e-02]]
# [-0.04906989 -0.05054277  1.56534156]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Smith, Luke : L
# [[ 1.35626100e+00  2.53387500e+00 -3.24739300e+00 ... -4.75867500e+00
#    3.86670000e-01 -2.33384100e+00]
#  [ 3.47161300e+00 -2.89532000e+00 -3.24695800e+00 ...  9.26430500e+00
#    9.60438800e+00  1.19458710e+01]
#  [ 8.16277423e+02  8.16277423e+02  8.16277423e+02 ...  4.46733300e+00
#    4.46733300e+00  4.41457200e+00]]
# [-0.04893465 -0.04903335  1.46302787]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Berch, Thaxton : R
# [[  5.919055   4.666781   6.365934 ...   5.542834   8.197001   9.08933 ]
#  [  6.81193   13.932013   9.967309 ...   5.312511   3.825978   6.359982]
#  [776.600161 776.600161 776.600161 ...  -4.532121   0.        -4.532121]]
# [-0.04871729 -0.04839657  1.22338065]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Evans, Karson : R
# [[ 1.56798280e+01  1.86952120e+01  2.08125390e+01 ...  7.05283400e+00
#    7.18868800e+00  1.10902110e+01]
#  [ 1.32604590e+01  1.29199100e+01  1.36263160e+01 ...  1.23124700e+00
#   -3.27228900e+00 -3.93654400e+00]
#  [ 9.70580552e+02  9.66048431e+02  9.66048431e+02 ... -4.53212100e+00
#    1.26610000e-02 -1.31622000e-01]]
# [-0.04816837 -0.04837866  1.20163083]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Davis, Dalton : R
# [[-2.10290310e+01 -1.18531590e+01 -1.33226190e+01 ... -3.56579900e+00
#   -2.27993300e+00 -2.54958600e+00]
#  [ 2.32064190e+01  2.40125660e+01  2.04466430e+01 ...  1.07120550e+01
#    5.59178900e+00  1.07559120e+01]
#  [ 8.72399802e+02  8.76800300e+02  8.85732920e+02 ...  0.00000000e+00
#    1.26610000e-02  4.54478200e+00]]
# [-0.04999833 -0.04768541  1.92967789]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Patterson, Cade : L
# [[-3.21856600e+00 -7.16747100e+00 -1.02464110e+01 ...  4.00254600e+00
#    8.14417500e+00  7.82636100e+00]
#  [-2.80256200e+00 -1.38735000e+00 -2.19322200e+00 ...  2.03179200e+00
#   -3.14731000e-01 -3.42314600e+00]
#  [ 8.08863859e+02  8.08863859e+02  8.08863859e+02 ...  8.91852600e+00
#    4.46733300e+00  0.00000000e+00]]
# [-0.04935383 -0.04917261  1.64371783]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Furr, Kasten : R
# [[ 7.73951900e+00  6.55173000e+00  5.10999900e+00 ...  7.19757000e-01
#    1.84708200e+00  1.78388900e+00]
#  [-5.41352900e+00 -4.27686800e+00 -8.64647000e+00 ...  8.19003400e+00
#    5.49477900e+00  4.10513300e+00]
#  [ 8.52559173e+02  8.52703457e+02  8.52703457e+02 ...  4.40049800e+00
#    1.26610000e-02  4.40049800e+00]]
# [-0.04863338 -0.0493341   1.29066397]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: LaRocca, Jake : R
# [[ 4.59583100e+00  8.01307700e+00  7.52509200e+00 ...  1.75765380e+01
#    1.82140890e+01  1.74992000e+01]
#  [ 3.16834600e+00 -1.49381100e+00  8.54716000e-01 ...  3.63409700e+00
#   -9.05814000e-01  4.84524000e+00]
#  [ 8.85505675e+02  8.85505675e+02  8.85505675e+02 ... -1.31622000e-01
#   -1.31622000e-01  4.41316000e+00]]
# [-0.04869445 -0.0490006   1.27979748]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Davis, Dalton : R
# [[  1.745024  -1.919772  -1.317544 ...  -8.841833  -4.101345 -11.063151]
#  [  4.574063   3.461151   9.053579 ...  -5.364089  -5.352225 -10.515046]
#  [850.239387 854.639886 859.19966  ...   8.945281   4.41316    4.544782]]
# [-0.0490539  -0.04881684  1.76859365]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: McConnell, Cole : L
# [[ 6.81180100e+00  5.13752700e+00 -1.09979900e+00 ... -6.89077900e+00
#   -7.04286600e+00 -1.24667900e+00]
#  [ 5.70177000e-01  6.51095300e+00  6.79985000e+00 ...  5.81438100e+00
#    4.95737400e+00  2.33430100e+00]
#  [ 9.17552995e+02  9.22004188e+02  9.13185427e+02 ...  4.46733300e+00
#    0.00000000e+00  4.46733300e+00]]
# [-0.04873098 -0.04886151  1.50923581]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Comeaux, Grant : R
# [[-5.24120700e+00 -3.74219000e+00 -6.75343000e+00 ... -6.67779800e+00
#   -1.97530200e+00 -7.23536100e+00]
#  [ 1.30713120e+01  1.66321260e+01  1.48214020e+01 ...  6.13493500e+00
#    8.61844600e+00  1.25290850e+01]
#  [ 8.41855480e+02  8.37310698e+02  8.41842819e+02 ... -4.53212100e+00
#   -4.53212100e+00  1.26610000e-02]]
# [-0.04931454 -0.04816738  1.61815857]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Brown, RJ : R
# [[-37.985822 -38.311955 -35.783913 ...  -8.007072  -7.54033   -7.42013 ]
#  [-32.261227 -33.194955 -40.116104 ...  -4.23814    7.827914   6.806531]
#  [800.88835  801.00265  805.53244  ...  -4.532121   0.        -4.532121]]
# [-0.05129079 -0.05097214  1.59507007]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Evans, Karson : R
# [[ 2.96149820e+01  3.09265600e+01  2.49360670e+01 ...  5.42637200e+00
#    3.90851100e+00  8.87528000e-01]
#  [ 4.65539440e+01  4.56401790e+01  4.17280030e+01 ...  8.39635900e+00
#    8.55386300e+00  5.72446600e+00]
#  [ 9.72580617e+02  9.72580617e+02  9.76996108e+02 ... -4.53212100e+00
#    0.00000000e+00 -4.53212100e+00]]
# [-0.04749688 -0.04668461  1.11055335]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Ballard, Mike : R
# [[ 1.04318830e+01  1.18224740e+01  6.48252500e+00 ...  2.57571100e+00
#   -3.17437000e-01  1.39579900e+00]
#  [-6.73758500e+00 -1.16375400e+00 -8.70515900e+00 ... -4.38244000e-01
#    4.89632900e+00  5.10032500e+00]
#  [ 8.81437350e+02  8.77036852e+02  8.81437350e+02 ...  4.54478200e+00
#   -4.53212100e+00  4.41316000e+00]]
# [-0.04842145 -0.04926976  1.27581437]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: McLeod, Logan : R
# [[ 2.96209100e+01  3.46135050e+01  3.00261370e+01 ...  2.85725500e+01
#    2.69798460e+01  2.60362640e+01]
#  [ 1.73453780e+01  1.80359190e+01  1.30552060e+01 ...  1.25964370e+01
#    9.64255400e+00  7.53054600e+00]
#  [ 8.26074246e+02  8.26074246e+02  8.26074246e+02 ... -4.40282900e+00
#   -1.49920000e-02 -1.49920000e-02]]
# [-0.0471229  -0.0479875   1.45002145]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: McLeod, Logan : R
# [[ 2.01735860e+01  1.94519280e+01  1.75686580e+01 ...  2.01598770e+01
#    2.28568380e+01  2.31922820e+01]
#  [ 1.69990640e+01  1.16403780e+01  1.06757950e+01 ...  2.33010000e+00
#    1.44600200e+00  2.76359200e+00]
#  [ 8.28957921e+02  8.28957921e+02  8.28957921e+02 ... -4.54711300e+00
#   -4.54711300e+00 -2.33100000e-03]]
# [-0.04786032 -0.04818952  1.46412586]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Safford, Will : L
# [[-12.860445 -13.515227 -13.976705 ...  10.680643  12.548118   9.342207]
#  [  2.793847   2.728181   0.940536 ...   1.703881   5.928781   4.709434]
#  [743.391662 747.858995 743.544187 ...   8.766001   8.766001   4.451193]]
# [-0.04990537 -0.04887322  1.39086116]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Corona, Jorge : R
# [[  6.220829   4.043623   3.63825  ...   7.999925  12.331648  10.431961]
#  [  8.900179  10.103337   7.66801  ...   7.635751  11.127957  10.080903]
#  [945.544085 945.544085 945.544085 ...   0.        -4.532121   0.      ]]
# [-0.04878461 -0.04855729  1.16396788]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Patterson, Cade : L
# [[  2.347535   4.351283  -2.728236 ...   4.465093  11.65252   12.092546]
#  [  9.303849   9.185998   7.784719 ...  -4.977614  -5.18661   -6.429341]
#  [833.354967 829.024019 820.241878 ...   8.918526   0.         0.      ]]
# [-0.04885415 -0.0485093   1.52467002]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Netterville, Slade : R
# [[-1.53417100e+00  1.51796100e+00  4.38768400e+00 ...  9.44832000e+00
#    5.87939200e+00  5.98351200e+00]
#  [ 1.23208550e+01  1.00436960e+01  5.62334000e+00 ...  9.24534500e+00
#    6.18506500e+00  3.93551700e+00]
#  [ 7.57289376e+02  7.57289376e+02  7.57289376e+02 ...  4.40049800e+00
#   -1.31622000e-01 -1.31622000e-01]]
# [-0.04905044 -0.04832124  1.47875409]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Alonso, Nick : R
# [[-4.95948000e+00 -6.87421600e+00 -9.85339800e+00 ... -2.39863300e+00
#   -6.84524000e-01 -1.40945500e+00]
#  [ 2.51783600e+00 -1.35016900e+00 -1.22544100e+00 ... -2.42929000e-01
#    9.34876000e-01 -9.52660000e-01]
#  [ 7.44824293e+02  7.44824293e+02  7.44824293e+02 ... -4.41549100e+00
#    0.00000000e+00  0.00000000e+00]]
# [-0.04943684 -0.04900832  0.96688005]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Patterson, Cade : L
# [[ 2.40746700e+00 -2.39098000e-01 -1.11035500e+00 ... -1.61004400e+00
#   -3.32516000e+00 -4.09810600e+00]
#  [ 1.41594560e+01  1.50144710e+01  9.35629200e+00 ... -7.88124300e+00
#   -5.91344300e+00 -8.30012000e+00]
#  [ 8.49060697e+02  8.49060697e+02  8.49060697e+02 ...  4.45119300e+00
#    4.45119300e+00  0.00000000e+00]]
# [-0.04898665 -0.04819683  1.5048191 ]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Guinn, Hutson : R
# [[ 5.80649300e+00  7.25145300e+00  8.61768300e+00 ... -1.16889360e+01
#   -5.78751000e+00 -8.19576900e+00]
#  [ 5.62182300e+00  2.71430500e+00  5.65309100e+00 ...  8.89777500e+00
#    1.11838030e+01  9.12167400e+00]
#  [ 8.93595190e+02  8.97995688e+02  8.93450906e+02 ...  8.94528100e+00
#   -1.31622000e-01 -1.31622000e-01]]
# [-0.04868782 -0.04881843  1.28808816]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Myers, Adarius : R
# [[-1.46306060e+01 -1.67769550e+01 -1.16114870e+01 ...  2.80361500e+00
#    3.03119800e+00  1.98192500e+00]
#  [ 1.02521290e+01  1.12660040e+01  9.09863200e+00 ... -8.57717700e+00
#   -1.17582250e+01 -9.04323500e+00]
#  [ 8.54075996e+02  8.54075996e+02  8.54075996e+02 ...  4.40049800e+00
#   -1.31622000e-01  4.40049800e+00]]
# [-0.04994821 -0.04843587  1.25882443]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Smith, Jake : R
# [[ 7.40327700e+00  5.38404400e+00  5.05424700e+00 ...  4.89105500e+00
#    3.94435600e+00  3.36181000e-01]
#  [ 1.97975310e+01  2.04491250e+01  1.44208140e+01 ...  2.02823700e+00
#    6.47392800e+00  7.59804600e+00]
#  [ 7.34779448e+02  7.30247327e+02  7.30247327e+02 ... -4.53212100e+00
#    4.40049800e+00 -1.31622000e-01]]
# [-0.0486235  -0.04770266  0.93604211]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Guinn, Hutson : R
# [[ 5.08874900e+00  1.17446000e+00 -7.04830000e-02 ... -9.98089600e+00
#   -9.54242200e+00 -8.64221900e+00]
#  [ 1.49150170e+01  1.37761780e+01  1.94809140e+01 ... -1.24310320e+01
#   -7.97827800e+00 -6.91947700e+00]
#  [ 8.94089965e+02  8.94089965e+02  8.94089965e+02 ... -4.53212100e+00
#    1.26610000e-02  0.00000000e+00]]
# [-0.04887577 -0.04825539  1.07924446]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Myers, Adarius : R
# [[-8.87668500e+00 -1.13110510e+01 -1.06601600e+01 ... -4.12846300e+00
#   -1.16782800e+00 -2.42839500e+00]
#  [ 2.65322000e+00  5.85019200e+00  1.26117800e+00 ... -8.90888300e+00
#   -4.61481000e+00 -7.72571600e+00]
#  [ 8.62790347e+02  8.62790347e+02  8.62790347e+02 ... -1.31622000e-01
#    4.41316000e+00 -1.31622000e-01]]
# [-0.04962761 -0.04880777  1.5127817 ]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Furr, Kasten : R
# [[ 2.26138440e+01  2.03814400e+01  2.10479590e+01 ...  7.98346800e+00
#    1.11526630e+01  6.59232700e+00]
#  [ 7.74614040e+01  6.89827490e+01  7.73414510e+01 ...  1.99846900e+00
#    3.60817500e+00  4.14770600e+00]
#  [ 8.27864644e+02  8.27864644e+02  8.18904371e+02 ... -1.31622000e-01
#   -4.53212100e+00 -4.53212100e+00]]
# [-0.04779467 -0.04477197  1.20386784]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Berch, Thaxton : R
# [[ 7.06881500e+00  7.09241000e-01  4.09553500e+00 ...  7.93041600e+00
#   -1.16440000e+00 -1.11861900e+00]
#  [ 1.56230110e+01  1.66919680e+01  1.54187600e+01 ...  1.55156060e+01
#    1.29833040e+01  1.76365290e+01]
#  [ 7.77059312e+02  7.77059312e+02  7.77059312e+02 ... -8.94761200e+00
#   -8.94761200e+00 -8.94761200e+00]]
# [-0.04880595 -0.04803123  1.32789393]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: McConnell, Cole : L
# [[-2.40233600e+00 -3.59254100e+00 -3.78021300e+00 ... -6.71775100e+00
#   -3.98303100e+00 -1.52254900e+00]
#  [ 1.15328300e+01  6.70223900e+00  1.72877280e+01 ...  1.10539250e+01
#    1.12703420e+01  7.52864100e+00]
#  [ 9.24492725e+02  9.24492725e+02  9.20177917e+02 ...  4.46733300e+00
#   -3.66210000e-02 -3.66210000e-02]]
# [-0.04921211 -0.04856244  1.54249838]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Alonso, Nick : R
# [[-3.51659900e+00 -4.29049800e+00 -4.22388900e+00 ... -7.16213600e+00
#   -9.12381000e+00 -1.56939810e+01]
#  [-1.47639600e+00 -6.22211800e+00  3.29938400e+00 ... -2.33101000e+00
#   -2.75492900e+00 -6.83526000e-01]
#  [ 7.40177873e+02  7.40177873e+02  7.40177873e+02 ... -4.53212100e+00
#    0.00000000e+00 -4.53212100e+00]]
# [-0.04930412 -0.04930054  1.24132982]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Cobb, Baylor : L
# [[-8.84009500e+00 -8.96161100e+00 -1.08045440e+01 ... -1.71623000e+00
#   -1.03497570e+01 -7.13257100e+00]
#  [-4.13329900e+00 -3.89636200e+00 -4.45736100e+00 ...  8.60563300e+00
#    1.01871810e+01  8.50625500e+00]
#  [ 8.81132690e+02  8.85600023e+02  8.81096069e+02 ...  3.66210000e-02
#    3.66210000e-02  3.66210000e-02]]
# [-0.04955167 -0.04927541  1.71239242]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Smith, Jake : R
# [[-11.640961  -7.132073  -3.869413 ...  -8.3411    -5.769594  -4.245149]
#  [-29.54657  -29.261205 -28.894221 ...   6.034847   5.728301   7.688644]
#  [736.782052 736.782052 736.782052 ...  -4.532121   0.        -4.532121]]
# [-0.04968186 -0.05102441  1.04829369]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Snider, Reid : R
# [[ 2.11778230e+01  1.98367940e+01  2.36051460e+01 ...  6.86373400e+00
#    2.24266000e+00  2.06182600e+00]
#  [-4.43909800e+00 -2.98902000e-01  6.57822000e-01 ... -4.34902900e+00
#   -3.85261000e+00 -4.40141000e+00]
#  [ 8.38916873e+02  8.38916873e+02  8.34516375e+02 ... -1.31622000e-01
#    1.26610000e-02 -1.31622000e-01]]
# [-0.04784174 -0.04918899  1.2321745 ]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: McConnell, Cole : L
# [[ 1.21427960e+01  1.44432600e+01  1.55925030e+01 ... -8.61935000e-01
#   -1.71770000e-02  6.10754300e+00]
#  [-1.51010500e+00  1.11515400e+00  6.65942300e+00 ...  2.59167400e+00
#    3.43779400e+00  5.97725200e+00]
#  [ 8.71852641e+02  8.63070500e+02  8.54099213e+02 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]]
# [-0.04833853 -0.04906196  1.28399979]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Alonso, Nick : R
# [[ -2.516969  -5.21909   -4.967049 ...  -2.102643  -2.822279  -7.996902]
#  [  8.66722    6.853778   6.387418 ...  -4.306624  -4.835048  -1.776694]
#  [739.601714 739.601714 739.601714 ...  -4.532121  -4.532121  -4.532121]]
# [-0.04930178 -0.04853523  1.13256979]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Furr, Kasten : R
# [[ 1.61658520e+01  1.80287260e+01  1.69926550e+01 ... -2.50868800e+00
#    1.11721900e+00  8.64023000e-01]
#  [ 4.70018500e+00  5.89748100e+00  2.47982900e+00 ...  5.64642300e+00
#    5.33061000e-01  2.21196900e+00]
#  [ 8.19586557e+02  8.15054436e+02  8.15054436e+02 ... -4.54711300e+00
#   -4.54711300e+00 -4.54711300e+00]]
# [-0.04805182 -0.0487413   1.47444528]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Processing path: /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# Player name: Safford, Will : L
# [[ 3.10969180e+01  2.69148900e+01  2.63501210e+01 ...  7.15504000e-01
#   -1.52100100e+00  3.33158700e+00]
#  [ 1.36196990e+01  1.02414290e+01  1.38568010e+01 ...  6.40995000e-01
#    1.69424200e+00  2.14625500e+00]
#  [ 7.51918754e+02  7.47414800e+02  7.47414800e+02 ...  4.46733300e+00
#    0.00000000e+00  0.00000000e+00]]
# [-0.04717474 -0.0482798   1.6224356 ]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/drive_leg
# ...
# Player name: Furr, Kasten : L
# [[ -9.288368  -9.852612 -13.777995 ... -19.965152 -13.997456 -16.535673]
#  [-11.33971   -5.368359  -8.824188 ...   5.87475    8.271063   3.262737]
#  [874.246317 869.778984 865.464176 ...   0.         4.467333   0.      ]]
# [-0.04961024 -0.04953916  1.41048843]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Smith, Jake : L
# [[ -1.238831   0.779001   1.538377 ...   0.901637   2.29532    3.5466  ]
#  [-32.846016 -30.568039 -30.260975 ...  -4.847059  -4.705357  -4.559581]
#  [720.079669 720.268815 720.268815 ...   4.467333  -4.451193  -4.451193]]
# [-0.04906773 -0.05117888  0.89421651]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Cobb, Baylor : R
# [[-9.89473400e+00 -3.96180500e+00 -7.05159400e+00 ... -1.38617950e+01
#   -1.59647730e+01 -1.17724400e+01]
#  [ 8.15676400e+00  8.28530700e+00  9.18879500e+00 ... -2.04511400e+00
#   -3.83987300e+00  4.83752000e-01]
#  [ 8.66981195e+02  8.66981195e+02  8.66981195e+02 ...  0.00000000e+00
#    1.26610000e-02  1.26610000e-02]]
# [-0.04944014 -0.04858357  1.33879298]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Corona, Jorge : L
# [[ 3.62339400e+00 -2.20227000e-01  6.71624800e+00 ... -1.01519200e+00
#    2.73808700e+00 -2.16747100e+00]
#  [ 7.10940000e+00  9.48312600e+00  9.15287400e+00 ...  4.44858000e-01
#    1.72960500e+00  3.54447200e+00]
#  [ 9.37220659e+02  9.41724613e+02  9.46139185e+02 ...  0.00000000e+00
#   -4.50395400e+00  0.00000000e+00]]
# [-0.04896308 -0.04862001  1.27340703]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Patterson, Cade : R
# [[ 4.76379400e+00  3.47340000e+00  3.82363800e+00 ...  1.03602710e+01
#    8.11627800e+00  1.03318060e+01]
#  [ 5.44566600e+00  2.06818700e+00  1.59758500e+00 ... -1.91435700e+00
#   -2.54931400e+00 -1.48664700e+00]
#  [ 8.41017807e+02  8.41017807e+02  8.41017807e+02 ...  4.41316000e+00
#   -1.31622000e-01 -4.53212100e+00]]
# [-0.04880916 -0.04883032  1.01078572]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: LaRocca, Jake : L
# [[-2.29413000e-01 -2.10760800e+00  2.17622000e-01 ... -1.81831900e+00
#   -4.79879200e+00 -4.26280900e+00]
#  [-3.02099100e+00 -8.17163000e-01 -2.76373300e+00 ... -1.68768430e+01
#   -1.38206550e+01 -1.31792510e+01]
#  [ 9.04059093e+02  9.04059093e+02  9.04059093e+02 ...  8.91852600e+00
#    4.45119300e+00  0.00000000e+00]]
# [-0.04911292 -0.04915495  1.37190564]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Evans, Karson : L
# [[ -6.653028  -5.024892  -6.670024 ...  -8.766152  -9.891468  -5.384694]
#  [-22.543953 -23.038829 -25.468011 ...   3.714848  10.641553  10.94129 ]
#  [972.271203 976.775157 976.738536 ...   4.503954   4.503954   8.971287]]
# [-0.04935018 -0.05022025  1.25425581]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Ballard, Mike : L
# [[  9.00547    4.829041   3.688871 ...  -6.476179  -4.708351  -3.608895]
#  [  5.90304    7.135372   7.99599  ...   6.706572   6.39192    5.814091]
#  [888.632995 879.661709 875.194376 ...   8.818762   8.818762   4.503954]]
# [-0.04865831 -0.0486807   1.22188487]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: McLeod, Logan : L
# [[ 2.83485000e-01  1.80895800e+00  1.57745400e+00 ...  6.13188800e+00
#    3.67169100e+00  1.89439900e+00]
#  [ 1.11576180e+01  8.80252300e+00  1.14375310e+01 ...  1.21964490e+01
#    1.03494850e+01  1.19841270e+01]
#  [ 8.23083885e+02  8.18769077e+02  8.23083885e+02 ... -4.41457200e+00
#   -4.41457200e+00 -4.41457200e+00]]
# [-0.048985   -0.04844959  1.53179616]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Patterson, Cade : R
# [[ 5.24631000e-01 -6.74295000e-01  2.87837700e+00 ...  2.27191500e+00
#    3.35845700e+00  2.54678600e+00]
#  [-5.91773000e+00 -3.49102700e+00 -3.38235400e+00 ... -1.70261510e+01
#   -1.59024580e+01 -1.21090620e+01]
#  [ 8.45636197e+02  8.45636197e+02  8.45636197e+02 ... -1.31622000e-01
#    0.00000000e+00  0.00000000e+00]]
# [-0.04905445 -0.04932524  1.08990998]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Corona, Jorge : L
# [[ 8.96603100e+00  1.09621060e+01  5.79597800e+00 ...  6.19952200e+00
#    3.27533900e+00  5.73415100e+00]
#  [ 6.49697000e-01 -2.55733000e+00  3.02875500e+00 ... -3.56391000e-01
#    8.77247000e-01  2.95580100e+00]
#  [ 9.44768160e+02  9.49272114e+02  9.44768160e+02 ... -4.50395400e+00
#   -4.50395400e+00 -4.50395400e+00]]
# [-0.04853324 -0.04910123  1.39546943]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Comeaux, Grant : L
# [[ 18.87858   16.083855  13.489183 ...  -7.845821 -10.784591 -13.071872]
#  [-36.975109 -37.522429 -35.942903 ...  -9.981839  -1.906726  -4.040287]
#  [856.342574 851.875241 851.875241 ...   0.         0.         0.      ]]
# [-0.04801143 -0.05125719  1.80655273]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Alonso, Nick : L
# [[ -3.211627  -1.248036  -1.234363 ...  -3.551262  -6.43411   -4.421235]
#  [ -9.333981  -9.679343  -8.392488 ... -19.881973 -13.792824 -15.452992]
#  [737.836649 737.836649 737.836649 ...   0.         4.503954   4.503954]]
# [-0.04919379 -0.04967348  1.50483358]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: McLeod, Logan : L
# [[-1.16025890e+01 -5.00183800e+00 -1.35127770e+01 ...  7.19348800e+00
#    1.15079840e+01  1.28290350e+01]
#  [ 3.33865930e+01  3.17819060e+01  3.35216460e+01 ... -3.59465000e+00
#   -6.26388000e-01  1.05333500e+00]
#  [ 7.81749802e+02  7.90668328e+02  7.94983136e+02 ... -4.41457200e+00
#   -4.41457200e+00 -4.41457200e+00]]
# [-0.04954526 -0.04709491  1.34256819]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Patterson, Cade : R
# [[-1.85937000e-01 -4.79468100e+00  4.61753000e-01 ...  1.19153260e+01
#    1.05559410e+01  1.63030310e+01]
#  [-4.47888800e+00 -5.89424000e+00 -1.08102950e+01 ... -8.57302600e+00
#   -7.38677400e+00 -7.82834800e+00]
#  [ 8.46096296e+02  8.46096296e+02  8.46096296e+02 ... -1.31622000e-01
#    4.40049800e+00 -4.53212100e+00]]
# [-0.04919574 -0.04935345  1.3456192 ]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Snider, Reid : L
# [[-4.58387400e+00 -4.73448800e+00 -5.12349400e+00 ... -3.93592900e+00
#    7.98243000e-01  6.31562000e-01]
#  [ 2.34362860e+01  2.75118220e+01  2.92125830e+01 ...  1.41685100e+01
#    1.89385290e+01  1.41036560e+01]
#  [ 8.21981289e+02  8.22017910e+02  8.17703102e+02 ...  0.00000000e+00
#    0.00000000e+00  4.45119300e+00]]
# [-0.04932386 -0.04754923  1.36426874]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Myers, Adarius : L
# [[ -9.610634  -9.195972 -10.112357 ...  -6.094101  -3.63715   -3.490732]
#  [  0.918601   1.294291   5.168001 ... -15.217457 -11.305976  -9.29067 ]
#  [864.419787 864.283402 864.283402 ...   4.467333   0.         0.      ]]
# [-0.04958814 -0.04898752  1.67097664]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Evans, Karson : L
# [[ -7.81466   -6.164124  -8.013615 ...  -8.274996  -7.778881  -8.211487]
#  [  2.59277    8.193997   5.979842 ...   6.715614   5.809751   4.107196]
#  [979.351348 983.802541 979.335208 ...   4.503954   8.818762   4.503954]]
# [-0.04940923 -0.04877369  1.53116679]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Guinn, Hutson : L
# [[-42.220815 -37.810991 -42.376367 ...   7.458825   7.473705   3.463828]
#  [ 53.637131  51.509762  48.129161 ...  10.449822  10.173755   6.018153]
#  [860.330077 860.330077 860.482603 ...   0.         0.         4.451193]]
# [-0.05126277 -0.04614055  1.50318148]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Corona, Jorge : L
# [[ -3.401038  -4.465679  -3.598774 ...   1.902887   3.808073   3.004503]
#  [ -8.800375  -3.879327  -6.992017 ...   4.357159   6.294672   1.997013]
#  [939.758211 939.758211 939.758211 ...  -4.503954  -4.503954  -4.503954]]
# [-0.04925624 -0.04938143  1.26750451]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Netterville, Slade : L
# [[ 1.81818700e+00  5.32220200e+00  1.02769500e+00 ...  4.88281000e-01
#    2.94474400e+00  5.00373600e+00]
#  [-7.61778600e+00 -1.04637330e+01 -5.98053700e+00 ... -9.35595300e+00
#   -1.00415380e+01 -5.29471400e+00]
#  [ 7.47811244e+02  7.47811244e+02  7.52126052e+02 ... -4.41457200e+00
#   -4.41457200e+00 -4.41457200e+00]]
# [-0.04881727 -0.04963904  1.60994357]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Coates, Colton : L
# [[  6.515614  11.305691  14.192419 ...   1.408537   6.106859   4.248993]
#  [ -2.497234  -5.099667  -8.252396 ...  -6.375166  -7.154026  -4.629169]
#  [832.257817 827.943009 832.257817 ...   0.         4.503954   4.503954]]
# [-0.04852556 -0.04927509  1.57724769]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Brown, RJ : L
# [[-36.541519 -40.113345 -37.216413 ...  -9.654132 -10.278217 -11.704692]
#  [ 39.285323  36.654007  41.600521 ...   2.269563  -1.406698   1.2823  ]
#  [836.472192 840.939525 845.406858 ...   4.467333  -4.503954   4.451193]]
# [-0.05130128 -0.04681638  1.49236167]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Coates, Colton : L
# [[ -3.411171   4.367377  -1.319155 ... -10.023718  -6.40395   -8.986121]
#  [ -9.150842 -12.566597 -15.091034 ...  -3.574864  -5.871438  -6.782711]
#  [825.045317 825.045317 825.045317 ...   0.         0.         4.503954]]
# [-0.04902288 -0.04969148  1.32000102]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Berch, Thaxton : L
# [[ 22.70599   22.869592  24.727929 ...  21.121908  24.186422  20.94346 ]
#  [ 15.595815  14.615914  15.294815 ...   2.872853   3.999182  -1.313659]
#  [781.59234  781.60848  781.59234  ...  -4.503954   0.        -4.503954]]
# [-0.04761254 -0.04809763  1.3832766 ]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Safford, Will : R
# [[ 1.23637190e+01  1.75902320e+01  1.66269570e+01 ...  1.75565020e+01
#    1.34206520e+01  1.43825480e+01]
#  [-7.26601700e+00 -6.52827300e+00 -9.99232800e+00 ...  7.27716600e+00
#    2.95544700e+00  6.28620200e+00]
#  [ 7.54665261e+02  7.54665261e+02  7.59080752e+02 ... -1.31622000e-01
#    4.40049800e+00 -1.31622000e-01]]
# [-0.04808264 -0.04949826  1.36301535]
# /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /LMJ_BASEBALL/stride_leg
# Player name: Ballard, Mike : L
# [[ 1.09493400e+01  6.59927700e+00  9.08721000e+00 ... -9.69842500e+00
#   -9.48094700e+00 -5.77555200e+00]
#  [ 1.17289030e+01  7.62663700e+00  5.86277100e+00 ... -2.67529200e+00
#    1.27340800e+00  6.59885000e-01]
#  [ 8.79356659e+02  8.79356659e+02  8.79356659e+02 ...  4.50395400e+00
#    0.00000000e+00  4.50395400e+00]]
# [-0.04855383 -0.04850299  1.3455285 ]
# [-0.04818574 -0.05002724  1.82578611]
# [-0.04808418 -0.05058983  1.57996795]
# [-0.05443421 -0.05538435  1.77060891]
# [-0.04923058 -0.04894673  2.17476416]
# [-0.04825084 -0.05018025  1.88882966]
# [-0.05794763 -0.04985064  1.01623175]
# [-0.04239145 -0.04975275  1.9177717 ]
# [-0.04902522 -0.05022961  1.77091671]
# [-0.0432407  -0.04804647  1.84347154]
# [-0.0530009  -0.04904362  1.59897079]
# [-0.05173933 -0.04915867  2.0722004 ]
# [-0.05006905 -0.04998106  1.92598408]
# [-0.04806139 -0.04883993  1.7231272 ]
# [-0.04523565 -0.04875425  2.52357619]
# [-0.04663297 -0.05094817  1.71719104]
# [-0.04945661 -0.04868855  2.64181252]
# [-0.04590904 -0.05130611  2.67781622]
# [-0.05455146 -0.04853727  1.56546069]
# [-0.05348765 -0.04963199  2.24940745]
# [-0.04275396 -0.04834758  1.92910357]
# [-0.05209035 -0.04856889  2.07563108]
# [-0.05599526 -0.04894804  2.35090362]
# [-0.05122218 -0.04907595  1.57513732]
# [-0.04840094 -0.04902122  2.01770372]
# [-0.04807865 -0.05118332  1.91541431]
# [-0.05021662 -0.05027771  1.31530536]
# [-0.0423539  -0.05098234  1.69065615]
# [-0.05685624 -0.04919426  1.79851377]
# [-0.05362715 -0.04842922  2.31367974]
# [-0.04792857 -0.04882365  1.52354461]
# [-0.04863473 -0.04875563  1.64181752]
# [-0.05215174 -0.04936069  0.86869327]
# [-0.04959969 -0.05052639  1.6147057 ]
# [-0.05021046 -0.04803675  2.63413075]
# [-0.04094619 -0.04788158  2.36764156]
# [-0.04906024 -0.04981605  1.94590942]
# [-0.04366467 -0.04885554  1.87058439]
# [-0.04967001 -0.04894669  1.85110772]
# [-0.0495747  -0.05087369  2.36873184]
# [-0.04872878 -0.04711862  1.56071512]
# [-0.04783038 -0.05057112  1.88265917]
# [-0.048345   -0.05050046  1.93144751]
# [-0.04931888 -0.04942956  2.0137759 ]
# [-0.04501021 -0.04953393  1.0019303 ]
# [-0.04990001 -0.04904089  1.68337136]
# [-0.04713973 -0.04982675  1.37727373]
# [-0.04866903 -0.04890667  1.78822981]
# [-0.04370493 -0.04968926  1.68071872]
# [-0.04962686 -0.04811643  2.69070495]
# [-0.05687809 -0.04957191  2.08459779]
# [-0.05535383 -0.04944967  1.92088818]
# [-0.04967261 -0.05105116  1.75697819]
# [-0.04955416 -0.04813672  2.03721747]
# [-0.04766273 -0.04936274  1.30051368]
# [-0.04954307 -0.04986111  2.2350635 ]
# [-0.0559216  -0.04898653  2.20798275]
# [-0.05008563 -0.04956041  1.89599203]
# [-0.04855072 -0.04973175  2.21163981]
# [-0.05295507 -0.049289    1.59566569]
# [-0.05103339 -0.04928726  1.97351009]
# [-0.05109856 -0.0498978   1.65696363]
# [-0.04951916 -0.04883562  1.86528138]
# [-0.04952218 -0.04898028  1.79705475]
# [-0.04737425 -0.0485239   1.55982404]
# [-0.04931891 -0.05057698  1.77013237]
# [-0.05785307 -0.04804095  1.81155746]
# Data saved to /Users/charlesarnold/Library/Mobile Documents/com~apple~CloudDocs/Documents/Shared Documents/LA Tech/2023/Force_plate_Testing/BASEBALL /baseball_output_data.xlsx
